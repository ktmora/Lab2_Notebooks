# %%
import ugradio
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import ugradio
#
# ModuleNotFoundError: No module named 'ugradio'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\kathi\Coding\python.exe

# %%
# !pip show ugradio
# Out:
# WARNING: Package(s) not found: ugradio

# %%
# !pip list | grep ugradio
# Out:
# 'grep' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip install ugradio
# Out:
# ERROR: Could not find a version that satisfies the requirement ugradio (from versions: none)
# ERROR: No matching distribution found for ugradio

# %%
# !conda install -c conda-forge ugradio
